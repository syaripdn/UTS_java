// %%
    
    System.out.print("Masukan Sisi Disini : ");
    //keterangan user
    
    int sisi = input.nextInt();
    // menimpan nilai input user tipe data integer di variabel sisi
    
    int luasKubus = 6 *(sisi*sisi* );
    //menerapkan rumus luas kubus
    
    int volumeKubus = sisi * sisi *sisi;
    //menerapkan rumus volume kubus
    
    int kelilingKubus = 12 * sisi;
    //menerapkan rumus kelillung kubus
    
    System.out.println("Luas adalah :"+luasKubus");
    System.out.println("Volume adalah :"+volumeKubus");
    System.out.println("kelilling adalah :"+kelillingKubus");
    //Tampikan output hasil

}
// Out:
// ERROR: java.lang.IllegalStateException: <identifier> expected
//  System.out.print("Masukan Sisi Disini : ")
//                  ^
//
// illegal start of type
//  System.out.print("Masukan Sisi Disini : ")
//                   ^
//
// illegal start of expression
// int luasKubus = 6 *(sisi*sisi* )
//                                ^
//
// <identifier> expected
//  System.out.println("Luas adalah :"+luasKubus")
//                    ^
//
// illegal start of type
//  System.out.println("Luas adalah :"+luasKubus")
//                     ^
//
// ')' expected
// tem.out.println("Luas adalah :"+luasKubus")
//                                ^
//
// ';' expected
// em.out.println("Luas adalah :"+luasKubus")
//                                ^
//
// unclosed string literal
// intln("Luas adalah :"+luasKubus")
//                                ^
//
// illegal start of type
//  System.out.println("Volume adalah :"
//        ^
//
// ';' expected
//  System.out.println("Volume adalah :"+
// ...
